# %%
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.model_selection import KFold
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from my_linear_regression import MyLinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
rating = pd.read_csv("data/Rating.csv", delimiter=",")
teleplay = pd.read_csv("data/processed_teleplay.csv", delimiter=",")
teleplay.sort_values(["teleplay_id"], inplace=True)

# %%
UID = 53698
SEED = 4434
user_rating = rating.loc[rating["user_id"] == UID]
del rating  # save memory

# %%
# we save the rating of a particular user and the rating by all users
# as two separate feature.
merged = pd.merge(user_rating, teleplay, on="teleplay_id")

# %%
train = merged[merged["rating_x"] != -1]  # rated movies
y_train = train["rating_x"]
X_train = train.drop(["rating_x", "user_id"], axis=1)

# %%
kf = KFold(5)
# lr = MyLinearRegression()
# # lr = Lasso() #sklearn implementation as reference benchmark

lr_rmse = []
for train_index, test_index in kf.split(X_train):
    lr_X_train, lr_X_test = X_train.iloc[train_index], X_train.iloc[test_index]
    lr_y_train, lr_y_test = y_train.iloc[train_index], y_train.iloc[test_index]
    lr = MyLinearRegression()
    # lr = MyLinearRegression(poly_degree=2)

    lr.fit(lr_X_train, lr_y_train)
    lr_rmse.append(np.sqrt(mean_squared_error(
        lr.predict(lr_X_test), lr_y_test)))

print("LR, 5fold RMSE ", np.mean(lr_rmse))
# Out:
# LR, 5fold RMSE  1.273855669882478

# %%
mlp = tf.keras.models.Sequential()
mlp.add(tf.keras.layers.Input([48, ]))
mlp.add(tf.keras.layers.BatchNormalization())
mlp.add(tf.keras.layers.Dense(400, activation="sigmoid"))
mlp.add(tf.keras.layers.BatchNormalization())
mlp.add(tf.keras.layers.Dropout(0.4))
mlp.add(tf.keras.layers.Dense(400, activation="sigmoid"))
mlp.add(tf.keras.layers.Dense(1))

adam = tf.keras.optimizers.Adam(learning_rate=1e-4)
scheduler = tf.keras.callbacks.ReduceLROnPlateau()
es = tf.keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)
mlp.compile(loss=["mse"], metrics=["mse"], optimizer=adam)
mlp.summary()


def init_layer(layer):  # re-init nn
    session = K.get_session()
    weights_initializer = tf.variables_initializer(layer.weights)
    session.run(weights_initializer)


mlp_rmse = []
for train_index, test_index in kf.split(X_train):
    mlp_X_train, mlp_X_test = X_train.iloc[train_index], X_train.iloc[test_index]
    mlp_y_train, mlp_y_test = y_train.iloc[train_index], y_train.iloc[test_index]
    for layer in mlp.layers:
        init_layer(layer)
    mlp.fit(mlp_X_train, mlp_y_train, validation_data=[
            mlp_X_test, mlp_y_test], epochs=100, callbacks=[es, scheduler])
    mlp_rmse.append(np.sqrt(mean_squared_error(
        mlp.predict(mlp_X_test), mlp_y_test)))

print("MLP, 5fold RMSE ", np.mean(mlp_rmse))
# Out:
# WARNING:tensorflow:From /root/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 48)                192
# _________________________________________________________________
# dense (Dense)                (None, 400)               19600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 400)               1600
# _________________________________________________________________
# dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 182,193
# Trainable params: 181,297
# Non-trainable params: 896
# _________________________________________________________________
# Train on 1921 samples, validate on 481 samples
# Epoch 1/100
# 1921/1921 [==============================] - 3s 2ms/sample - loss: 32.3293 - mean_squared_error: 32.3293 - val_loss: 30.5652 - val_mean_squared_error: 30.5652
# Epoch 2/100
# 1921/1921 [==============================] - 0s 193us/sample - loss: 20.3617 - mean_squared_error: 20.3617 - val_loss: 19.0098 - val_mean_squared_error: 19.0098
# Epoch 3/100
# 1921/1921 [==============================] - 0s 206us/sample - loss: 12.2558 - mean_squared_error: 12.2558 - val_loss: 11.6499 - val_mean_squared_error: 11.6499
# Epoch 4/100
# 1921/1921 [==============================] - 0s 188us/sample - loss: 7.2937 - mean_squared_error: 7.2937 - val_loss: 7.0333 - val_mean_squared_error: 7.0333
# Epoch 5/100
# 1921/1921 [==============================] - 0s 191us/sample - loss: 4.4265 - mean_squared_error: 4.4265 - val_loss: 4.3852 - val_mean_squared_error: 4.3852
# Epoch 6/100
# 1921/1921 [==============================] - 0s 195us/sample - loss: 2.8387 - mean_squared_error: 2.8387 - val_loss: 2.8038 - val_mean_squared_error: 2.8038
# Epoch 7/100
# 1921/1921 [==============================] - 0s 180us/sample - loss: 2.1529 - mean_squared_error: 2.1529 - val_loss: 2.0652 - val_mean_squared_error: 2.0652
# Epoch 8/100
# 1921/1921 [==============================] - 0s 189us/sample - loss: 1.8551 - mean_squared_error: 1.8551 - val_loss: 1.7362 - val_mean_squared_error: 1.7362
# Epoch 9/100
# 1921/1921 [==============================] - 0s 200us/sample - loss: 1.6925 - mean_squared_error: 1.6925 - val_loss: 1.5952 - val_mean_squared_error: 1.5952
# Epoch 10/100
# 1921/1921 [==============================] - 0s 203us/sample - loss: 1.5853 - mean_squared_error: 1.5853 - val_loss: 1.5193 - val_mean_squared_error: 1.5193
# Epoch 11/100
# 1921/1921 [==============================] - 0s 191us/sample - loss: 1.6062 - mean_squared_error: 1.6062 - val_loss: 1.4893 - val_mean_squared_error: 1.4893
# Epoch 12/100
# 1921/1921 [==============================] - 0s 197us/sample - loss: 1.5752 - mean_squared_error: 1.5752 - val_loss: 1.4747 - val_mean_squared_error: 1.4747
# Epoch 13/100
# 1921/1921 [==============================] - 0s 190us/sample - loss: 1.5415 - mean_squared_error: 1.5415 - val_loss: 1.4814 - val_mean_squared_error: 1.4814
# Epoch 14/100
# 1921/1921 [==============================] - 0s 181us/sample - loss: 1.5729 - mean_squared_error: 1.5729 - val_loss: 1.4820 - val_mean_squared_error: 1.4820
# Epoch 15/100
# 1921/1921 [==============================] - 0s 186us/sample - loss: 1.5399 - mean_squared_error: 1.5399 - val_loss: 1.4728 - val_mean_squared_error: 1.4728
# Epoch 16/100
# 1921/1921 [==============================] - 0s 187us/sample - loss: 1.5716 - mean_squared_error: 1.5716 - val_loss: 1.4689 - val_mean_squared_error: 1.4689
# Epoch 17/100
# 1921/1921 [==============================] - 0s 182us/sample - loss: 1.5523 - mean_squared_error: 1.5523 - val_loss: 1.4891 - val_mean_squared_error: 1.4891
# Epoch 18/100
# 1921/1921 [==============================] - 0s 187us/sample - loss: 1.5555 - mean_squared_error: 1.5555 - val_loss: 1.4691 - val_mean_squared_error: 1.4691
# Epoch 19/100
# 1921/1921 [==============================] - 0s 191us/sample - loss: 1.5565 - mean_squared_error: 1.5565 - val_loss: 1.4506 - val_mean_squared_error: 1.4506
# Epoch 20/100
# 1921/1921 [==============================] - 0s 181us/sample - loss: 1.5384 - mean_squared_error: 1.5384 - val_loss: 1.4620 - val_mean_squared_error: 1.4620
# Epoch 21/100
# 1921/1921 [==============================] - 0s 191us/sample - loss: 1.5507 - mean_squared_error: 1.5507 - val_loss: 1.4612 - val_mean_squared_error: 1.4612
# Epoch 22/100
# 1921/1921 [==============================] - 0s 205us/sample - loss: 1.5253 - mean_squared_error: 1.5253 - val_loss: 1.4582 - val_mean_squared_error: 1.4582
# Epoch 23/100
# 1921/1921 [==============================] - 0s 250us/sample - loss: 1.5467 - mean_squared_error: 1.5467 - val_loss: 1.4782 - val_mean_squared_error: 1.4782
# Train on 1921 samples, validate on 481 samples
# Epoch 1/100
# 1921/1921 [==============================] - 0s 209us/sample - loss: 29.4992 - mean_squared_error: 29.4992 - val_loss: 10.7369 - val_mean_squared_error: 10.7369
# Epoch 2/100
# 1921/1921 [==============================] - 0s 187us/sample - loss: 7.5748 - mean_squared_error: 7.5748 - val_loss: 3.3041 - val_mean_squared_error: 3.3041
# Epoch 3/100
# 1921/1921 [==============================] - 0s 189us/sample - loss: 2.8404 - mean_squared_error: 2.8404 - val_loss: 2.0735 - val_mean_squared_error: 2.0735
# Epoch 4/100
# 1921/1921 [==============================] - 0s 186us/sample - loss: 1.8325 - mean_squared_error: 1.8325 - val_loss: 1.8679 - val_mean_squared_error: 1.8679
# Epoch 5/100
# 1921/1921 [==============================] - 0s 183us/sample - loss: 1.6370 - mean_squared_error: 1.6370 - val_loss: 1.7914 - val_mean_squared_error: 1.7914
# Epoch 6/100
# 1921/1921 [==============================] - 0s 195us/sample - loss: 1.5977 - mean_squared_error: 1.5977 - val_loss: 1.7445 - val_mean_squared_error: 1.7445
# Epoch 7/100
# 1921/1921 [==============================] - 0s 188us/sample - loss: 1.5591 - mean_squared_error: 1.5591 - val_loss: 1.7313 - val_mean_squared_error: 1.7313
# Epoch 8/100
# 1921/1921 [==============================] - 0s 197us/sample - loss: 1.5510 - mean_squared_error: 1.5510 - val_loss: 1.7136 - val_mean_squared_error: 1.7136
# Epoch 9/100
# 1921/1921 [==============================] - 0s 185us/sample - loss: 1.5475 - mean_squared_error: 1.5475 - val_loss: 1.6780 - val_mean_squared_error: 1.6780
# Epoch 10/100
# 1921/1921 [==============================] - 0s 172us/sample - loss: 1.5335 - mean_squared_error: 1.5335 - val_loss: 1.6751 - val_mean_squared_error: 1.6751
# Epoch 11/100
# 1921/1921 [==============================] - 0s 201us/sample - loss: 1.5434 - mean_squared_error: 1.5434 - val_loss: 1.6758 - val_mean_squared_error: 1.6758
# Epoch 12/100
# 1921/1921 [==============================] - 0s 207us/sample - loss: 1.5139 - mean_squared_error: 1.5139 - val_loss: 1.6799 - val_mean_squared_error: 1.6799
# Epoch 13/100
# 1921/1921 [==============================] - 0s 199us/sample - loss: 1.5191 - mean_squared_error: 1.5191 - val_loss: 1.6938 - val_mean_squared_error: 1.6938
# Epoch 14/100
# 1921/1921 [==============================] - 0s 194us/sample - loss: 1.5006 - mean_squared_error: 1.5006 - val_loss: 1.6881 - val_mean_squared_error: 1.6881
# Train on 1922 samples, validate on 480 samples
# Epoch 1/100
# 1922/1922 [==============================] - 0s 189us/sample - loss: 39.7355 - mean_squared_error: 39.7355 - val_loss: 17.5429 - val_mean_squared_error: 17.5429
# Epoch 2/100
# 1922/1922 [==============================] - 0s 186us/sample - loss: 10.2200 - mean_squared_error: 10.2200 - val_loss: 5.3485 - val_mean_squared_error: 5.3485
# Epoch 3/100
# 1922/1922 [==============================] - 0s 192us/sample - loss: 3.4873 - mean_squared_error: 3.4873 - val_loss: 2.6014 - val_mean_squared_error: 2.6014
# Epoch 4/100
# 1922/1922 [==============================] - 0s 178us/sample - loss: 1.9979 - mean_squared_error: 1.9979 - val_loss: 2.0313 - val_mean_squared_error: 2.0313
# Epoch 5/100
# 1922/1922 [==============================] - 0s 195us/sample - loss: 1.6441 - mean_squared_error: 1.6441 - val_loss: 1.9099 - val_mean_squared_error: 1.9099
# Epoch 6/100
# 1922/1922 [==============================] - 0s 189us/sample - loss: 1.5663 - mean_squared_error: 1.5663 - val_loss: 1.8889 - val_mean_squared_error: 1.8889
# Epoch 7/100
# 1922/1922 [==============================] - 0s 189us/sample - loss: 1.5590 - mean_squared_error: 1.5590 - val_loss: 1.8917 - val_mean_squared_error: 1.8917
# Epoch 8/100
# 1922/1922 [==============================] - 0s 200us/sample - loss: 1.5519 - mean_squared_error: 1.5519 - val_loss: 1.9052 - val_mean_squared_error: 1.9052
# Epoch 9/100
# 1922/1922 [==============================] - 0s 208us/sample - loss: 1.5518 - mean_squared_error: 1.5518 - val_loss: 1.9324 - val_mean_squared_error: 1.9324
# Epoch 10/100
# 1922/1922 [==============================] - 0s 209us/sample - loss: 1.4918 - mean_squared_error: 1.4918 - val_loss: 1.9843 - val_mean_squared_error: 1.9843
# Train on 1922 samples, validate on 480 samples
# Epoch 1/100
# 1922/1922 [==============================] - 0s 188us/sample - loss: 26.2008 - mean_squared_error: 26.2008 - val_loss: 10.1254 - val_mean_squared_error: 10.1254
# Epoch 2/100
# 1922/1922 [==============================] - 0s 182us/sample - loss: 7.4071 - mean_squared_error: 7.4071 - val_loss: 3.1183 - val_mean_squared_error: 3.1183
# Epoch 3/100
# 1922/1922 [==============================] - 0s 198us/sample - loss: 2.8723 - mean_squared_error: 2.8723 - val_loss: 1.8154 - val_mean_squared_error: 1.8154
# Epoch 4/100
# 1922/1922 [==============================] - 0s 192us/sample - loss: 1.8409 - mean_squared_error: 1.8409 - val_loss: 1.6837 - val_mean_squared_error: 1.6837
# Epoch 5/100
# 1922/1922 [==============================] - 0s 194us/sample - loss: 1.6327 - mean_squared_error: 1.6327 - val_loss: 1.6735 - val_mean_squared_error: 1.6735
# Epoch 6/100
# 1922/1922 [==============================] - 0s 177us/sample - loss: 1.5946 - mean_squared_error: 1.5946 - val_loss: 1.6484 - val_mean_squared_error: 1.6484
# Epoch 7/100
# 1922/1922 [==============================] - 0s 190us/sample - loss: 1.5810 - mean_squared_error: 1.5810 - val_loss: 1.6358 - val_mean_squared_error: 1.6358
# Epoch 8/100
# 1922/1922 [==============================] - 0s 180us/sample - loss: 1.5590 - mean_squared_error: 1.5590 - val_loss: 1.6273 - val_mean_squared_error: 1.6273
# Epoch 9/100
# 1922/1922 [==============================] - 0s 201us/sample - loss: 1.5511 - mean_squared_error: 1.5511 - val_loss: 1.6278 - val_mean_squared_error: 1.6278
# Epoch 10/100
# 1922/1922 [==============================] - 0s 193us/sample - loss: 1.5417 - mean_squared_error: 1.5417 - val_loss: 1.6350 - val_mean_squared_error: 1.6350
# Epoch 11/100
# 1922/1922 [==============================] - 0s 194us/sample - loss: 1.5560 - mean_squared_error: 1.5560 - val_loss: 1.6590 - val_mean_squared_error: 1.6590
# Epoch 12/100
# 1922/1922 [==============================] - 0s 189us/sample - loss: 1.5356 - mean_squared_error: 1.5356 - val_loss: 1.6637 - val_mean_squared_error: 1.6637
# Train on 1922 samples, validate on 480 samples
# Epoch 1/100
# 1922/1922 [==============================] - 0s 197us/sample - loss: 26.0418 - mean_squared_error: 26.0418 - val_loss: 9.7184 - val_mean_squared_error: 9.7184
# Epoch 2/100
# 1922/1922 [==============================] - 0s 190us/sample - loss: 6.9521 - mean_squared_error: 6.9521 - val_loss: 2.6655 - val_mean_squared_error: 2.6655
# Epoch 3/100
# 1922/1922 [==============================] - 0s 192us/sample - loss: 2.7576 - mean_squared_error: 2.7576 - val_loss: 1.4306 - val_mean_squared_error: 1.4306
# Epoch 4/100
# 1922/1922 [==============================] - 0s 175us/sample - loss: 1.9419 - mean_squared_error: 1.9419 - val_loss: 1.1846 - val_mean_squared_error: 1.1846
# Epoch 5/100
# 1922/1922 [==============================] - 0s 184us/sample - loss: 1.7794 - mean_squared_error: 1.7794 - val_loss: 1.1261 - val_mean_squared_error: 1.1261
# Epoch 6/100
# 1922/1922 [==============================] - 0s 199us/sample - loss: 1.6893 - mean_squared_error: 1.6893 - val_loss: 1.1145 - val_mean_squared_error: 1.1145
# Epoch 7/100
# 1922/1922 [==============================] - 0s 195us/sample - loss: 1.6440 - mean_squared_error: 1.6440 - val_loss: 1.1527 - val_mean_squared_error: 1.1527
# Epoch 8/100
# 1922/1922 [==============================] - 0s 182us/sample - loss: 1.7021 - mean_squared_error: 1.7021 - val_loss: 1.1674 - val_mean_squared_error: 1.1674
# Epoch 9/100
# 1922/1922 [==============================] - 0s 196us/sample - loss: 1.6311 - mean_squared_error: 1.6311 - val_loss: 1.1969 - val_mean_squared_error: 1.1969
# Epoch 10/100
# 1922/1922 [==============================] - 0s 198us/sample - loss: 1.6564 - mean_squared_error: 1.6564 - val_loss: 1.2209 - val_mean_squared_error: 1.2209
# MLP, 5fold RMSE  1.2408821056596326

# %%
lr.fit(X_train, y_train)

# %%
pred_rating = lr.predict(teleplay)
pred_rating = pd.DataFrame(pred_rating)

# %%
id_ = teleplay.teleplay_id.astype("int")
pred = pd.DataFrame(np.column_stack((id_, pred_rating)))
pred[0] = pred[0].astype("int")
pred.rename(columns={0: "Teleplay_id",
                     1: "Predicted rating"}, inplace=True)

# %%
pred.to_csv("19079662D_task2.csv", index=False)
